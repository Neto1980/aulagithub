# %% [markdown]
# <a href="https://colab.research.google.com/github/Neto1980/aulagithub/blob/main/Curso_de_Estat%C3%ADstica_Parte_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# # <font color=green size=10>CURSO DE ESTATÍSTICA - PARTE 1</font>
# ***

# %% [markdown]
# # <font color=green>1 CONHECENDO OS DADOS</font>
# ***

# %% [markdown]
# ## <font color=green>1.1 Dataset do projeto</font>
# ***

# %% [markdown]
# ### Pesquisa Nacional por Amostra de Domicílios - 2015
#
# A <b>Pesquisa Nacional por Amostra de Domicílios - PNAD</b> investiga anualmente, de forma permanente, características gerais da população, de educação, trabalho, rendimento e habitação e outras, com periodicidade variável, de acordo com as necessidades de informação para o país, como as características sobre migração, fecundidade, nupcialidade, saúde, segurança alimentar, entre outros temas. O levantamento dessas estatísticas constitui, ao longo dos 49 anos de realização da pesquisa, um importante instrumento para formulação, validação e avaliação de políticas orientadas para o desenvolvimento socioeconômico e a melhoria das condições de vida no Brasil.

# %% [markdown]
# ### Fonte dos Dados
#
# https://ww2.ibge.gov.br/home/estatistica/populacao/trabalhoerendimento/pnad2015/microdados.shtm

# %% [markdown]
# ### Variáveis utilizadas
#
# > ### Renda
# > ***
#
# Rendimento mensal do trabalho principal para pessoas de 10 anos ou mais de idade.
#
# > ### Idade
# > ***
#
# Idade do morador na data de referência em anos.
#
# > ### Altura (elaboração própria)
# > ***
#
# Altura do morador em metros.
#
# > ### UF
# > ***
#
# |Código|Descrição|
# |---|---|
# |11|Rondônia|
# |12|Acre|
# |13|Amazonas|
# |14|Roraima|
# |15|Pará|
# |16|Amapá|
# |17|Tocantins|
# |21|Maranhão|
# |22|Piauí|
# |23|Ceará|
# |24|Rio Grande do Norte|
# |25|Paraíba|
# |26|Pernambuco|
# |27|Alagoas|
# |28|Sergipe|
# |29|Bahia|
# |31|Minas Gerais|
# |32|Espírito Santo|
# |33|Rio de Janeiro|
# |35|São Paulo|
# |41|Paraná|
# |42|Santa Catarina|
# |43|Rio Grande do Sul|
# |50|Mato Grosso do Sul|
# |51|Mato Grosso|
# |52|Goiás|
# |53|Distrito Federal|
#
# > ### Sexo
# > ***
#
# |Código|Descrição|
# |---|---|
# |0|Masculino|
# |1|Feminino|
#
# > ### Anos de Estudo
# > ***
#
# |Código|Descrição|
# |---|---|
# |1|Sem instrução e menos de 1 ano|
# |2|1 ano|
# |3|2 anos|
# |4|3 anos|
# |5|4 anos|
# |6|5 anos|
# |7|6 anos|
# |8|7 anos|
# |9|8 anos|
# |10|9 anos|
# |11|10 anos|
# |12|11 anos|
# |13|12 anos|
# |14|13 anos|
# |15|14 anos|
# |16|15 anos ou mais|
# |17|Não determinados|
# ||Não aplicável|
#
# > ### Cor
# > ***
#
# |Código|Descrição|
# |---|---|
# |0|Indígena|
# |2|Branca|
# |4|Preta|
# |6|Amarela|
# |8|Parda|
# |9|Sem declaração|

# %% [markdown]
# #### <font color='red'>Observação</font>
# ***
# > Os seguintes tratamentos foram realizados nos dados originais:
# > 1. Foram eliminados os registros onde a <b>Renda</b> era inválida (999 999 999 999);
# > 2. Foram eliminados os registros onde a <b>Renda</b> era missing;
# > 3. Foram considerados somente os registros das <b>Pessoas de Referência</b> de cada domicílio (responsável pelo domicílio).

# %% [markdown]
# ### Importando pandas e lendo o dataset do projeto
#
# https://pandas.pydata.org/

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados.csv')

# %%
# Exibe os 5 primeiros campos
dados
# Out:
#        UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0      11     0     23    8              12    800  1.603808
# 1      11     1     23    2              12   1150  1.739790
# 2      11     1     35    8              15    880  1.760444
# 3      11     0     46    2               6   3500  1.783158
# 4      11     1     47    8               9    150  1.690631
# ...    ..   ...    ...  ...             ...    ...       ...
# 76835  53     1     46    2              11    812  1.687030
# 76836  53     0     30    4               7   1500  1.792934
# 76837  53     0     32    8              12   1300  1.830587
# 76838  53     0     57    8               4   1500  1.726344
# 76839  53     0     38    8               4    900  1.658305
#
# [76840 rows x 7 columns]

# %%
# Exibindo os 5 primeiros registros
dados.head()
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0  11     0     23    8              12    800  1.603808
# 1  11     1     23    2              12   1150  1.739790
# 2  11     1     35    8              15    880  1.760444
# 3  11     0     46    2               6   3500  1.783158
# 4  11     1     47    8               9    150  1.690631

# %% [markdown]
# ## <font color=green>1.2 Tipos de dados</font>
# ***

# %% [markdown]
# ### Variáveis qualitativas ordinais
#
# ► Variáveis que podem ser ordenadas ou hierarquizardas

# %%
sorted(dados['Anos de Estudo'].unique())
# Out:
# [np.int64(1),
#  np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9),
#  np.int64(10),
#  np.int64(11),
#  np.int64(12),
#  np.int64(13),
#  np.int64(14),
#  np.int64(15),
#  np.int64(16),
#  np.int64(17)]

# %% [markdown]
# ### Variáveis qualitativas nominais
#
# ► Variáveis que não podem ser ordenadas ou hierarquizardas

# %%
sorted(dados['UF'].unique())
# Out:
# [np.int64(11),
#  np.int64(12),
#  np.int64(13),
#  np.int64(14),
#  np.int64(15),
#  np.int64(16),
#  np.int64(17),
#  np.int64(21),
#  np.int64(22),
#  np.int64(23),
#  np.int64(24),
#  np.int64(25),
#  np.int64(26),
#  np.int64(27),
#  np.int64(28),
#  np.int64(29),
#  np.int64(31),
#  np.int64(32),
#  np.int64(33),
#  np.int64(35),
#  np.int64(41),
#  np.int64(42),
#  np.int64(43),
#  np.int64(50),
#  np.int64(51),
#  np.int64(52),
#  np.int64(53)]

# %%
sorted(dados['Sexo'].unique())
# Out:
# [np.int64(0), np.int64(1)]

# %%
sorted(dados['Cor'].unique())
# Out:
# [np.int64(0), np.int64(2), np.int64(4), np.int64(6), np.int64(8)]

# %% [markdown]
# ### Variáveis quantitativas discretas
#
# ► Variáveis que representam uma contagem onde os valores possíveis formam um conjunto finito ou enumerável.

# %%
print('As idades variam de %s até %s' % (dados.Idade.min(), dados.Idade.max()))
# Out:
# As idades variam de 13 até 99

# %% [markdown]
# #### <font color='red'>Observação</font>
# ***
# > A variável idade pode ser classificada de três formas distintas:
# > 1. <b>QUANTITATIVA DISCRETA</b> - quando representa anos completos (números inteiros);
# > 2. <b>QUANTITATIVA CONTÍNUA</b> - quando representa a idade exata, sendo representado por frações de anos; e
# > 3. <b>QUALITATIVA ORDINAL</b> - quando representa faixas de idade.

# %% [markdown]
# ### Variáveis quantitativas contínuas
#
# ► Variáveis que representam uma contagem ou mensuração que assumem valores em uma escala contínua (números reais).

# %%
#Alturas
print('As alturas variam de %s até %s' % (dados.Altura.min(), dados.Altura.max()))
# Out:
# As alturas variam de 1.339244614 até 2.028496765

# %% [markdown]
# ### Classificação de uma variável
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img001.png' width='70%'>

# %% [markdown]
# # <font color=green>2 DISTRIBUIÇÃO DE FREQUÊNCIAS</font>
# ***
#
# O primeiro passo em um trabalho de análise é o conhecimento do comportamento das variáveis envolvidas no estudo. Utilizando técnicas estatísticas como as análises das <b>DISTRIBUIÇÕES DE FREQUÊNCIAS</b> e <b>HISTOGRAMAS</b> podemos avaliar melhor a forma como os fenômenos em estudo se distribuem.

# %% [markdown]
# ## <font color=green>2.1 Distribuição de frequências para variáveis qualitativas</font>
# ***

# %% [markdown]
# ### Método 1

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.Series.value_counts.html

# %%
#Contar a quantidade de pessoas do sexo M(0) e F(1):
dados['Sexo'].value_counts()
# Out:
# Sexo
# 0    53250
# 1    23590
# Name: count, dtype: int64

# %%
#Transformaremos os dados acima em dados percentuais:
dados['Sexo'].value_counts(normalize = True) * 100
# Out:
# Sexo
# 0    69.299844
# 1    30.700156
# Name: proportion, dtype: float64

# %%
# Colocando os valores em uma variável:
frequencia = dados['Sexo'].value_counts()

# %%
percentual = dados['Sexo'].value_counts(normalize = True) * 100

# %%
# Criando um data frame com a biblioteca 'Pandas':
dist_freq_qualitativas = pd.DataFrame({'Frequência': frequencia, 'Porcentagem (%)': percentual})

# %%
dist_freq_qualitativas
# Out:
#       Frequência  Porcentagem (%)
# Sexo
# 0          53250        69.299844
# 1          23590        30.700156

# %%
# Adicionando legendas para o sexo (labels) - Salvando
dist_freq_qualitativas.rename(index = {0: 'Masculino', 1: 'Feminino'},inplace = True)
# Alterando a coluna 'Sexo'
dist_freq_qualitativas.rename_axis('Sexo' , axis = 'columns', inplace = True)

# %%
dist_freq_qualitativas
# Out:
# Sexo       Frequência  Porcentagem (%)
# Sexo
# Masculino       53250        69.299844
# Feminino        23590        30.700156

# %% [markdown]
# ### Método 2

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.crosstab.html

# %%
sexo = {0: 'Masculino',
        1: 'Feminino'}

cor = {0: 'Indígena',
        2: 'Branca',
        4: 'Preta',
        6: 'Amarela',
        8: 'Parda',
        9: 'Sem declaração'}

# %%
# Cruzando valores no data frame como Cor e Frequência:
frequencia = pd.crosstab(dados.Sexo, dados.Cor)
frequencia
# Out:
# Cor     0      2     4    6      8
# Sexo
# 0     256  22194  5502  235  25063
# 1     101   9621  2889  117  10862

# %%
# Alterando o Index para Masculino e feminino:
frequencia = pd.crosstab(dados.Sexo, dados.Cor)
frequencia.rename(index = sexo, inplace = True)
frequencia
# Out:
# Cor          0      2     4    6      8
# Sexo
# Masculino  256  22194  5502  235  25063
# Feminino   101   9621  2889  117  10862

# %%
# Alteraremos as colunas, nomeando-as com as cores definidas no dicionário:
frequencia = pd.crosstab(dados.Sexo, dados.Cor)
frequencia.rename(index = sexo, inplace = True)
frequencia.rename(columns = cor, inplace = True)
frequencia
# Out:
# Cor        Indígena  Branca  Preta  Amarela  Parda
# Sexo
# Masculino       256   22194   5502      235  25063
# Feminino        101    9621   2889      117  10862

# %%
# Criaremos um data frame com os percentuais, adicionando o 'normalize = True':
percentual = pd.crosstab(dados.Sexo, dados.Cor, normalize = True) * 100
percentual.rename(index = sexo, inplace = True)
percentual.rename(columns = cor, inplace = True)
percentual
# Out:
# Cor        Indígena     Branca     Preta   Amarela      Parda
# Sexo
# Masculino  0.333160  28.883394  7.160333  0.305830  32.617126
# Feminino   0.131442  12.520822  3.759761  0.152264  14.135867

# %%
# Iremos criar um data frame que mostre a media das rendas,  de acordo com as cores:
percentual = pd.crosstab(dados.Sexo, dados.Cor, aggfunc = 'mean', values = dados.Renda)
percentual.rename(index = sexo, inplace = True)
percentual.rename(columns = cor, inplace = True)
percentual
# Out:
# Cor           Indígena       Branca        Preta      Amarela        Parda
# Sexo
# Masculino  1081.710938  2925.744435  1603.861687  4758.251064  1659.577425
# Feminino   2464.386139  2109.866750  1134.596400  3027.341880  1176.758516

# %% [markdown]
# ## <font color=green>2.2 Distribuição de frequências para variáveis quantitativas (classes personalizadas)</font>
# ***

# %% [markdown]
# ### Passo 1 - Especificar os limites de cada classe
#
# Utilizar a seguinte classificação:
#
# <b>A</b> ► Acima de 20 SM
#
# <b>B</b> ► De 10 a 20 SM
#
# <b>C</b> ► De 4 a 10 SM
#
# <b>D</b> ► De 2 a 4 SM
#
# <b>E</b> ► Até 2 SM
#
# onde <b>SM</b> é o valor do salário mínimo na época. Em nosso caso <b>R$ 788,00</b> (2015):
#
# <b>A</b> ► Acima de 15.760
#
# <b>B</b> ► De 7.880 a 15.760
#
# <b>C</b> ► De 3.152 a 7.880
#
# <b>D</b> ► De 1.576 a 3.152
#
# <b>E</b> ► Até 1.576

# %%
# Primeiro passo é descobrir quais são os valores mínimos em máximos:
dados["Renda"].min()
# Out:
# 0

# %%
dados.Renda.max()
# Out:
# 200000

# %%
# vamos criar as classes, que estarão em uma lista:
classes = [0, 1576, 3152, 7880, 15760, 200000]

# %%
# Vamos criar os labels:
labels = ["E", "D", "C", "B", "A"]

# %% [markdown]
# ### Passo 2 - Criar a tabela de frequências

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.cut.html

# %%
# Criando a tabela utilizando o "CUT"
frequencia = pd.value_counts(
    pd.cut(x = dados.Renda,
       bins = classes,
       labels = labels,
       include_lowest = True)
    )
# Out:
# /tmp/ipykernel_371/918399330.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frequencia = pd.value_counts(

# %%
# Vamos passar esses dados para percentual, com o parâmetro "normalize = True"
frequencia = pd.value_counts(
    pd.cut(x = dados.Renda,
       bins = classes,
       labels = labels,
       include_lowest = True)
    )
frequencia
# Out:
# /tmp/ipykernel_371/2828505087.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frequencia = pd.value_counts(
# Renda
# E    49755
# D    16700
# C     7599
# B     2178
# A      608
# Name: count, dtype: int64

# %%
percentual = pd.value_counts(
    pd.cut(x = dados.Renda,
       bins = classes,
       labels = labels,
       include_lowest = True),
    normalize = True
    )
percentual
# Out:
# /tmp/ipykernel_371/470539280.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   percentual = pd.value_counts(
# Renda
# E    0.647514
# D    0.217335
# C    0.098894
# B    0.028345
# A    0.007913
# Name: proportion, dtype: float64

# %%
dist_freq_quantitativa_personalizadas = pd.DataFrame(
    {'Frequência': frequencia, 'Porcentagem (%)': percentual}
    )
dist_freq_quantitativa_personalizadas
# Out:
#        Frequência  Porcentagem (%)
# Renda
# E           49755         0.647514
# D           16700         0.217335
# C            7599         0.098894
# B            2178         0.028345
# A             608         0.007913

# %%
# Ordenando pelo indice
dist_freq_quantitativa_personalizadas.sort_index(ascending = False)
# Out:
#        Frequência  Porcentagem (%)
# Renda
# A             608         0.007913
# B            2178         0.028345
# C            7599         0.098894
# D           16700         0.217335
# E           49755         0.647514

# %% [markdown]
# ## <font color=green>2.3 Distribuição de frequências para variáveis quantitativas (classes de amplitude fixa)</font>
# ***

# %% [markdown]
# ### Importando bibliotecas
#
# http://www.numpy.org/

# %%
classes = [dados.Altura.min(), 1.65, 1.75, dados.Altura.max()]
labels = ['1 - Baixa', '2 - Média', '3 - Alta']

frequencia = pd.value_counts(
    pd.cut(
        x = dados.Altura,
        bins = classes,
        labels = labels,
        include_lowest = True
    )
)

percentual = pd.value_counts(
    pd.cut(
        x = dados.Altura,
        bins = classes,
        labels = labels,
        include_lowest = True
    ), normalize = True
) * 100

dist_freq_altura = pd.DataFrame(
    {'Frequência': frequencia, 'Porcentagem (%)': percentual}
)

dist_freq_altura.rename_axis('Estaturas', axis= 'columns', inplace = True)

dist_freq_altura.sort_index(ascending = True, inplace = True)

dist_freq_altura
# Out:
# /tmp/ipykernel_371/1120227437.py:4: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frequencia = pd.value_counts(
# /tmp/ipykernel_371/1120227437.py:13: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   percentual = pd.value_counts(
# Estaturas  Frequência  Porcentagem (%)
# Altura
# 1 - Baixa       20529        26.716554
# 2 - Média       36162        47.061426
# 3 - Alta        20149        26.222020

# %%
# Importando bibliotecas:
import numpy as np

# %% [markdown]
# ### Passo 1 - Difinindo o número de classes

# %% [markdown]
# #### Regra de Sturges
#
# # $$k = 1 + \frac {10}{3}\log_{10}n$$

# %%
# Para definir o numero de classe, teremos que utilizar a formula acima e acharmos o n:
n = dados.shape[0]
n
# Out:
# 76840

# %%
# Vamos aplicar a fórmula:
k = 1 + (10 / 3) * np.log10(n)
k
# Out:
# np.float64(17.285291187298853)

# %%
# Vamos arredondar para saber a quantidade de classes que necessitamos. São 17 classes:
k = int(k.round(0))
k
# Out:
# 17

# %% [markdown]
# ### Passo 2 - Criar a tabela de frequências

# %%
# Padrão é a ordenação pela frequencia e não pelas classes:
pd.value_counts(
    pd.cut(
        x = dados.Renda,
        bins = 17,
        include_lowest = True
    )
)
# Out:
# /tmp/ipykernel_371/3951211681.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(
# Renda
# (-200.001, 11764.706]       75594
# (11764.706, 23529.412]       1022
# (23529.412, 35294.118]        169
# (35294.118, 47058.824]         19
# (47058.824, 58823.529]         16
# (94117.647, 105882.353]         6
# (58823.529, 70588.235]          5
# (70588.235, 82352.941]          4
# (188235.294, 200000.0]          3
# (82352.941, 94117.647]          1
# (117647.059, 129411.765]        1
# (129411.765, 141176.471]        0
# (105882.353, 117647.059]        0
# (141176.471, 152941.176]        0
# (152941.176, 164705.882]        0
# (164705.882, 176470.588]        0
# (176470.588, 188235.294]        0
# Name: count, dtype: int64

# %%
# Ordenar pelas classes:
pd.value_counts(
    pd.cut(
        x = dados.Renda,
        bins = 17,
        include_lowest = True
    ),
    sort = False
)
# Out:
# /tmp/ipykernel_371/680654178.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(
# Renda
# (-200.001, 11764.706]       75594
# (11764.706, 23529.412]       1022
# (23529.412, 35294.118]        169
# (35294.118, 47058.824]         19
# (47058.824, 58823.529]         16
# (58823.529, 70588.235]          5
# (70588.235, 82352.941]          4
# (82352.941, 94117.647]          1
# (94117.647, 105882.353]         6
# (105882.353, 117647.059]        0
# (117647.059, 129411.765]        1
# (129411.765, 141176.471]        0
# (141176.471, 152941.176]        0
# (152941.176, 164705.882]        0
# (164705.882, 176470.588]        0
# (176470.588, 188235.294]        0
# (188235.294, 200000.0]          3
# Name: count, dtype: int64

# %%
# Vamos passar isso para a variavel frequencia:
frequencia = pd.value_counts(
    pd.cut(
        x = dados.Renda,
        bins = 17,
        include_lowest = True
    ),
    sort = False
)
# Out:
# /tmp/ipykernel_371/3035602827.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frequencia = pd.value_counts(

# %%
# Vamos criar a variável porcentagem:
percentual = pd.value_counts(
    pd.cut(
        x = dados.Renda,
        bins = 17,
        include_lowest = True
    ),
    normalize = True,
    sort = False
)
# Out:
# /tmp/ipykernel_371/2858107010.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   percentual = pd.value_counts(

# %%
dist_freq_quantitativa_amplitude_fixa = pd.DataFrame(
    {'Frequência': frequencia, 'Porcentagem (%)': percentual}
    )
dist_freq_quantitativa_amplitude_fixa
# Out:
#                           Frequência  Porcentagem (%)
# Renda
# (-200.001, 11764.706]          75594         0.983784
# (11764.706, 23529.412]          1022         0.013300
# (23529.412, 35294.118]           169         0.002199
# (35294.118, 47058.824]            19         0.000247
# (47058.824, 58823.529]            16         0.000208
# (58823.529, 70588.235]             5         0.000065
# (70588.235, 82352.941]             4         0.000052
# (82352.941, 94117.647]             1         0.000013
# (94117.647, 105882.353]            6         0.000078
# (105882.353, 117647.059]           0         0.000000
# (117647.059, 129411.765]           1         0.000013
# (129411.765, 141176.471]           0         0.000000
# (141176.471, 152941.176]           0         0.000000
# (152941.176, 164705.882]           0         0.000000
# (164705.882, 176470.588]           0         0.000000
# (176470.588, 188235.294]           0         0.000000
# ...

# %% [markdown]
# ## <font color=green>2.4 Histograma</font>
# ***
#
# O <b>HISTOGRAMA</b> é a representação gráfica de uma distribuição de frequências. É uma gráfico formado por um conjunto de retângulos colocados lado a lado, onde a área de cada retângulo é proporcional à frequência da classe que ele representa.

# %% [markdown]
# ### Importando a biblioteca
#
# https://seaborn.pydata.org/

# %%
import seaborn as sns

# %%
# Criando um histograma levando em consideração a Altura (KDE False)
ax = sns.distplot(dados.Altura, kde = False)

ax.figure.set_size_inches(12, 6)
ax.set_title('Distribuição de Frequências - Altura', fontsize=18)
ax.set_xlabel('Metros', fontsize=14)
ax
# Out:
# /tmp/ipykernel_371/371351920.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dados.Altura, kde = False)
# <Axes: title={'center': 'Distribuição de Frequências - Altura'}, xlabel='Metros'>

# %%
# Histograma levando em consideração a Altura (KDE True)
ax = sns.distplot(dados.Altura)

ax.figure.set_size_inches(12, 6)
ax.set_title('Distribuição de Frequências - Altura - KDE', fontsize=18)
ax.set_xlabel('Metros', fontsize=14)
ax
# Out:
# /tmp/ipykernel_371/1139204356.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dados.Altura)
# <Axes: title={'center': 'Distribuição de Frequências - Altura - KDE'}, xlabel='Metros', ylabel='Density'>

# %%
dados.Altura.hist(bins = 50, figsize=(12,6))
# Out:
# <Axes: >

# %%
dist_freq_quantitativa_personalizadas
# Out:
#        Frequência  Porcentagem (%)
# Renda
# E           49755         0.647514
# D           16700         0.217335
# C            7599         0.098894
# B            2178         0.028345
# A             608         0.007913

# %%
dist_freq_quantitativa_personalizadas['Frequência'].plot.bar(width= 1, color= 'blue', alpha = 0.2, figsize= (12, 6))
# Out:
# <Axes: xlabel='Renda'>

# %% [markdown]
# # <font color=green>3 MEDIDAS DE TENDÊNCIA CENTRAL</font>
# ***

# %% [markdown]
# ## DataFrame de exemplo

# %%
df = pd.DataFrame(data = {'Fulano': [8, 10, 4, 8, 6, 10, 8],
                          'Beltrano': [10, 2, 0.5, 1, 3, 9.5, 10],
                          'Sicrano': [7.5, 8, 7, 8, 8, 8.5, 7]},
                 index = ['Matemática',
                          'Português',
                          'Inglês',
                          'Geografia',
                          'História',
                          'Física',
                          'Química'])
df.rename_axis('Matérias', axis = 'columns', inplace = True)
df
# Out:
# Matérias    Fulano  Beltrano  Sicrano
# Matemática       8      10.0      7.5
# Português       10       2.0      8.0
# Inglês           4       0.5      7.0
# Geografia        8       1.0      8.0
# História         6       3.0      8.0
# Física          10       9.5      8.5
# Química          8      10.0      7.0

# %% [markdown]
# ## <font color=green>3.1 Média aritmética</font>
# ***
#
# É representada por $\mu$ quando se refere à população e por $\bar{X}$ quando se refere à amostra
#
# # $$\mu = \frac 1n\sum_{i=1}^{n}X_i$$
#
# onde
#
# $n$ = número de observações (registros)
#
# $X_i$ = valor da i-ésima observação (registro)

# %%
(8 + 10 + 4 + 8 + 6 + 10 + 8) / 7
# Out:
# 7.714285714285714

# %%
# Calculando a mesma média de outra forma:

df["Fulano"].mean()
# Out:
# np.float64(7.714285714285714)

# %%
# Calculando a média da renda:

dados.Renda.mean()
# Out:
# np.float64(2000.3831988547631)

# %%
# Exibindo os 5 primeiros registros do Data Frame:

dados.Renda.head()
# Out:
# 0     800
# 1    1150
# 2     880
# 3    3500
# 4     150
# Name: Renda, dtype: int64

# %%
# Tirando a média por grupo "Sexo" - Resultado a média dos grupos Masculino e Feminino
# e de todas as colunas, gerando Erro! já que as variáveis qualitativas não podem ter suas médias
# calculadas:

dados.groupby(['Sexo']).mean()
# Out:
#              UF      Idade       Cor  Anos de Estudo        Renda    Altura
# Sexo
# 0     31.901991  44.046554  5.038685        9.120169  2192.441596  1.699443
# 1     31.937728  44.127554  5.018906       10.258584  1566.847393  1.699670

# %%
# Certo - Calculando a média das rendas por Sexo:

dados.groupby(['Sexo'])["Renda"].mean()
# Out:
# Sexo
# 0    2192.441596
# 1    1566.847393
# Name: Renda, dtype: float64

# %%
'''Exercício - Obtenha a média aritmética do data frame.'''

dataset = pd.DataFrame({
    'Sexo': ['H', 'M', 'M', 'M', 'M', 'H', 'H', 'H', 'M', 'M'],
    'Idade': [53, 72, 54, 27, 30, 40, 58, 32, 44, 51]
})

dataset["Idade"].mean()
# Out:
# np.float64(46.1)

# %%
'''Exercício 2 - Obtenha a média aritmética dos homens.'''

dataset = pd.DataFrame({
    'Sexo': ['H', 'M', 'M', 'M', 'M', 'H', 'H', 'H', 'M', 'M'],
    'Idade': [53, 72, 54, 27, 30, 40, 58, 32, 44, 51]
})

dataset.loc[dataset['Sexo'] == 'H', 'Idade'].mean()
# Out:
# np.float64(45.75)

# %%
# Calculando a média através do "groupBy"

dataset.groupby('Sexo')['Idade'].mean()['H']
# Out:
# np.float64(45.75)

# %%
# 3ª Solução:

dataset.groupby('Sexo').mean().loc['H']
# Out:
# Idade    45.75
# Name: H, dtype: float64

# %% [markdown]
# ## <font color=green>3.2 Mediana</font>
# ***
#
# Para obtermos a mediana de uma conjunto de dados devemos proceder da seguinte maneira:
# 1. Ordenar o conjunto de dados;
# 2. Identificar o número de observações (registros) do conjunto de dados ($n$);
# 3. Identicar o elemento mediano:
#
# > Quando $n$ for ímpar, a posição do elemento mediano será obtida da seguinte forma:
#
#
# # $$Elemento_{Md} = \frac{n+1}2$$
#
# > Quando $n$ for par, a posição do elemento mediano será obtida da seguinte forma:
#
#
# # $$Elemento_{Md} = \frac{n}2$$
#
# 4. Obter a mediana:
#
# > Quando $n$ for ímpar:
#
#
# # $$Md = X_{Elemento_{Md}}$$
#
# > Quando $n$ for par:
#
#
# # $$Md = \frac{X_{Elemento_{Md}} + X_{Elemento_{Md}+1}}2$$
# ***

# %% [markdown]
# ### Exemplo 1 - n ímpar
#
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img002.png' width='40%' style="float:left">

# %%
notas_fulano = df.Fulano
notas_fulano
# Out:
# Matemática     8
# Português     10
# Inglês         4
# Geografia      8
# História       6
# Física        10
# Química        8
# Name: Fulano, dtype: int64

# %%
# Vamos organizar os valores em ordem crescente:

notas_fulano = notas_fulano.sort_values()
notas_fulano
# Out:
# Inglês         4
# História       6
# Geografia      8
# Matemática     8
# Química        8
# Português     10
# Física        10
# Name: Fulano, dtype: int64

# %%
# Criando um Indice:

notas_fulano = notas_fulano.reset_index()
notas_fulano
# Out:
#         index  Fulano
# 0      Inglês       4
# 1    História       6
# 2   Geografia       8
# 3  Matemática       8
# 4     Química       8
# 5   Português      10
# 6      Física      10

# %%
# Acessando a quantidade de elementos, que é igual a 7:

n = notas_fulano.shape[0]
n
# Out:
# 7

# %%
# Calcularemos o elemento mediano, que será o elemento que representará a mediana:

elemento_md = (n + 1) / 2
elemento_md
# Out:
# 4.0

# %%
# O elemento mediano está na posição 4 porém como se trata de elementos impares, devemos subtrair por 1.
# Obs. o comando 'loc' é um comando de localização.

notas_fulano.loc[elemento_md - 1]
# Out:
# index     Matemática
# Fulano             8
# Name: 3, dtype: object

# %%
# Método '.median()' que faz a mesma coisa que o comando acima.

notas_fulano.median(numeric_only=True)
# Out:
# Fulano    8.0
# dtype: float64

# %% [markdown]
# ### Exemplo 2 - n par
#
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img003.png' width='50%' style="float:left">

# %%
# Acessando 6 notas de beltrano:

notas_beltrano = df.Beltrano.sample(6, random_state = 101)
notas_beltrano
# Out:
# Matemática    10.0
# Inglês         0.5
# Física         9.5
# História       3.0
# Química       10.0
# Português      2.0
# Name: Beltrano, dtype: float64

# %%
# Acessando as notas de Beltrano:

df['Beltrano']
# Out:
# Matemática    10.0
# Português      2.0
# Inglês         0.5
# Geografia      1.0
# História       3.0
# Física         9.5
# Química       10.0
# Name: Beltrano, dtype: float64

# %%
# Obtendo a mediana das notas de beltrano:

notas_beltrano.median(numeric_only=True)
# Out:
# 6.25

# %% [markdown]
# ### Obtendo a mediana em nosso dataset

# %%
# 1ª forma de obter a mediana:

dados.Renda.median()
# Out:
# 1200.0

# %%
# 2ª forma de obter a mediana, através do método 'quantile()':

dados.Renda.quantile()
# Out:
# np.float64(1200.0)

# %% [markdown]
# ## <font color=green>3.3 Moda</font>
# ***
#
# Pode-se definir a moda como sendo o valor mais frequente de um conjunto de dados. A moda é bastante utilizada para dados qualitativos.

# %%
# Exibindo o dataframe:
df
# Out:
# Matérias    Fulano  Beltrano  Sicrano
# Matemática       8      10.0      7.5
# Português       10       2.0      8.0
# Inglês           4       0.5      7.0
# Geografia        8       1.0      8.0
# História         6       3.0      8.0
# Física          10       9.5      8.5
# Química          8      10.0      7.0

# %%
# Exibindo a moda de cada estudante:
df.mode()
# Out:
# Matérias  Fulano  Beltrano  Sicrano
# 0              8      10.0      8.0

# %%
# Um exemplo de variável multimodal:
exemplo = pd.Series([1, 2, 2, 3, 4, 4, 5, 6, 6])

# %%
# Exibindo os valores modais
exemplo.mode()
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %% [markdown]
# ### Obtendo a moda em nosso dataset

# %%
# Exibindo a moda de nosso df renda:
dados.Renda.mode()
# Out:
# 0    788
# Name: Renda, dtype: int64

# %%
# Exibindo a moda da variavel altura:
dados.Altura.mode()
# Out:
# 0    1.568128
# 1    1.671225
# 2    1.681659
# 3    1.692977
# 4    1.708163
# 5    1.708370
# 6    1.753842
# 7    1.779073
# 8    1.796462
# Name: Altura, dtype: float64

# %% [markdown]
# ## <font color=green>3.4 Relação entre média, mediana e moda</font>
# ***

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img004.png' width='80%'>

# %% [markdown]
# ### Avaliando a variável RENDA

# %%
# Temos um exemplo de assimetria a direita:
ax = sns.distplot(dados.query("Renda<20000").Renda)
ax.figure.set_size_inches(12, 6)
ax
# Out:
# /tmp/ipykernel_371/3260897973.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dados.query("Renda<20000").Renda)
# <Axes: xlabel='Renda', ylabel='Density'>

# %%
# Calculando a Moda
moda = dados.Renda.mode()[0]
moda
# Out:
# np.int64(788)

# %%
# Calculando a Mediana
mediana = dados.Renda.median()
mediana
# Out:
# 1200.0

# %%
# Calculando a Média
media = dados.Renda.mean()
media
# Out:
# np.float64(2000.3831988547631)

# %%
moda < mediana < media
# Out:
# np.True_

# %% [markdown]
# ***

# %% [markdown]
# ### Avaliando a variável ALTURA

# %%
ax = sns.distplot(dados.Altura)
ax.figure.set_size_inches(12, 6)
ax
# Out:
# /tmp/ipykernel_371/1709077983.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dados.Altura)
# <Axes: xlabel='Altura', ylabel='Density'>

# %%
# Temos o exemplo de uma variável multimodal:
Moda = dados.Altura.mode()
Moda
# Out:
# 0    1.568128
# 1    1.671225
# 2    1.681659
# 3    1.692977
# 4    1.708163
# 5    1.708370
# 6    1.753842
# 7    1.779073
# 8    1.796462
# Name: Altura, dtype: float64

# %%
mediana = dados.Altura.median()
mediana
# Out:
# 1.6993247325

# %%
media = dados.Altura.mean()
media
# Out:
# np.float64(1.6995124540575741)

# %% [markdown]
# ***

# %% [markdown]
# ### Avaliando a variável ANOS DE ESTUDO

# %%
ax = sns.distplot(dados['Anos de Estudo'], bins = 17)
ax = figure.set_size_inches(12, 6)
ax
# Out:
# /tmp/ipykernel_371/959165928.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dados['Anos de Estudo'], bins = 17)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_371/959165928.py in <cell line: 0>()
#       1 ax = sns.distplot(dados['Anos de Estudo'], bins = 17)
# ----> 2 ax = figure.set_size_inches(12, 6)
#       3 ax
#
# NameError: name 'figure' is not defined

# %%
# Moda de 'Anos de Estudo':
moda = dados['Anos de Estudo'].mode()
moda

# %%
# Mediana de 'Anos de Estudo':
mediana = dados['Anos de Estudo'].median()
mediana

# %%
# Média de 'Anos de Estudo':
media = dados['Anos de Estudo'].mean()
media

# %% [markdown]
# # <font color=green>4 MEDIDAS SEPARATRIZES</font>
# ***

# %% [markdown]
# ## <font color=green>4.1 Quartis, decis e percentis</font>
# ***
#
# Há uma série de medidas de posição semelhantes na sua concepção à mediana, embora não sejam medidas de tendência central. Como se sabe, a mediana divide a distribuição em duas partes iguais quanto ao número de elementos de cada parte. Já os quartis permitem dividir a distribuição em quatro partes iguais quanto ao número de elementos de cada uma; os decis em dez partes e os centis em cem partes iguais.

# %%
dados.Renda.quantile()

# %%
# Dividiremos a renda em 4 partes, chamada de quartil:
dados.Renda.quantile([0.25, 0.5, 0.75])

# %%
# Vamos dividir a renda em decil, 10 partes:
[i / 10 for i in range(1, 10)]

# %%
dados.Renda.quantile([i / 10 for i in range(1, 10)])

# %%
dados.Renda.quantile([i / 100 for i in range(1, 100)])

# %%
# Faremos a representação gráfica da variável idade:
ax = sns.distplot(dados.Idade,
                  hist_kws = {'cumulative': True},
                  kde_kws = {'cumulative': True})
ax.figure.set_size_inches(14, 6)
ax.set_title('Distribuição de Frequências Acumulada', fontsize=18)
ax.set_ylabel('Acumulado', fontsize=14)
ax.set_xlabel('Anos', fontsize=14)
ax

# %%
dados.Idade.quantile([i/10 for i in range(1, 10)])

# %%
ax = sns.distplot(dados.Idade,
                  hist_kws = {'cumulative': True},
                  kde_kws = {'cumulative': True},
                  bins = 10)
ax.figure.set_size_inches(14, 6)
ax.set_title('Distribuição de Frequências Acumulada', fontsize=18)
ax.set_ylabel('Acumulado', fontsize=14)
ax.set_xlabel('Anos', fontsize=14)
ax

# %% [markdown]
# ## <font color=green>4.2 Box-plot</font>
# ***
#
# O box plot dá uma idéia da posição, dispersão, assimetria, caudas e dados discrepantes (outliers). A posição central é dada pela mediana e a dispersão por $IIQ$. As posições relativas de $Q1$, $Mediana$ e $Q3$ dão uma noção da simetria da distribuição. Os comprimentos das cauda são dados pelas linhas que vão do retângulo aos valores remotos e pelos valores atípicos.

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img005.png' width='65%'>

# %%
# Construindo o box-plot:
ax = sns.boxplot( x = 'Altura', data = dados, orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Altura', fontsize=18)
ax.set_xlabel('Metros', fontsize=14)
ax

# %%
# Criando a variável sexo na variavel Y para fins de comparação:
ax = sns.boxplot( x = 'Altura', y = 'Sexo', data = dados, orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Altura', fontsize=18)
ax.set_xlabel('Metros', fontsize=14)
ax

# %%
ax = sns.boxplot( x = 'Renda', data = dados, orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Renda', fontsize=18)
ax.set_xlabel('R$', fontsize=14)
ax

# %%
# Selecionando as pessoas que recebem menos que R$ 10.000,00 reais:
ax = sns.boxplot( x = 'Renda', data = dados.query('Renda < 10000'), orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Renda', fontsize=18)
ax.set_xlabel('R$', fontsize=14)
ax

# %%
# Inserindo a variável sexo: Notamos que o sexo feminino (1) tem uma renda mensal menor que a do homem.
ax = sns.boxplot( x = 'Renda', y = 'Sexo', data = dados.query('Renda < 10000'), orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Renda', fontsize=18)
ax.set_xlabel('R$', fontsize=14)
ax

# %%
# Grafico com os anos de estudo:
ax = sns.boxplot( x = 'Anos de Estudo', data = dados, orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Anos de Estudo', fontsize=18)
ax.set_xlabel('Anos', fontsize=14)
ax

# %%
# Adicionaremos a variável sexo para compararmos o tempo de estudo entre as mulheres e os homens:
ax = sns.boxplot( x = 'Anos de Estudo', y = 'Sexo', data = dados, orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Anos de Estudo', fontsize=18)
ax.set_xlabel('Anos', fontsize=14)
ax

# %%
# Comparativo entre rendas de dois estados: São Paulo x Bahia
ax = sns.boxplot(x = 'Renda', y = 'UF', data = dados.query('(UF==35 or UF==29) and Renda < 10000'), orient = 'h')
ax.figure.set_size_inches(12, 6)
ax.set_title('Renda (R$) - Bahia X São Paulo', fontsize=18)
ax.set_xlabel('R$', fontsize=14)
ax

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img006.png' width='80%'>

# %% [markdown]
# # <font color=green>5 MEDIDAS DE DISPERSÃO</font>
# ***
#
# Embora as medidas de posição forneçam uma sumarização bastante importante dos dados, elas podem não ser suficientes para caracterizar conjuntos distintos, especialmente quando as observações de determinada distribuição apresentarem dados muito dispersos.

# %% [markdown]
# ## <font color=green>5.1 Desvio médio absoluto</font>
# ***
#
#
# # $$DM = \frac 1n\sum_{i=1}^{n}|X_i-\bar{X}|$$

# %%
# Começaremos com o data frame:
df

# %%
# Obs. 1 colchete - Cria uma Series | 2 colchetes - cria um data frame
notas_fulano = df[['Fulano']]
notas_fulano

# %%
# Media de fulano:
nota_media_fulano = notas_fulano.mean()[0]
nota_media_fulano

# %%
notas_fulano['Desvio'] = notas_fulano['Fulano'] - nota_media_fulano
notas_fulano

# %%
# Somo todas as notas do desvio:
notas_fulano['Desvio'].sum()

# %%
# Pegando os valores absolutos
notas_fulano['|Desvio|'] = notas_fulano['Desvio'].abs()
notas_fulano

# %%
# Grafico de demonstração da variável AX:
ax = notas_fulano['Fulano'].plot(style = 'o')
ax.figure.set_size_inches(14, 6)
ax.hlines(y = nota_media_fulano, xmin = 0, xmax = notas_fulano.shape[0] - 1, colors = 'red')
for i in range(notas_fulano.shape[0]):
    ax.vlines(x = i, ymin = nota_media_fulano, ymax = notas_fulano['Fulano'][i], linestyle='dashed')
ax

# %%
# Media das 7 marcações:
notas_fulano['|Desvio|'].mean()

# %%
# Forma correta de calcular o Desvio Médio Absoluto
desvio_medio_absoluto = (notas_fulano['Fulano'] - notas_fulano['Fulano'].mean()).abs().mean()
desvio_medio_absoluto

# %% [markdown]
# ## <font color=green>5.2 Variância</font>
# ***

# %% [markdown]
# ### Variância
#
# A variância é construída a partir das diferenças entre cada observação e a média dos dados, ou seja, o desvio em torno da média. No cálculo da variância, os desvios em torno da média são elevados ao quadrado.

# %% [markdown]
# ### Variância populacional
#
# # $$\sigma^2 = \frac 1n\sum_{i=1}^{n}(X_i-\mu)^2$$

# %% [markdown]
# ### Variância amostral
#
# # $$S^2 = \frac 1{n-1}\sum_{i=1}^{n}(X_i-\bar{X})^2$$

# %%
notas_fulano['Desvio'] = notas_fulano['Fulano'] - notas_fulano['Fulano'].mean()
notas_fulano['(Desvio)^2'] = notas_fulano['Desvio'].pow(2)
notas_fulano
# Out:
#         index  Fulano    Desvio  (Desvio)^2
# 0      Inglês       4 -3.714286   13.795918
# 1    História       6 -1.714286    2.938776
# 2   Geografia       8  0.285714    0.081633
# 3  Matemática       8  0.285714    0.081633
# 4     Química       8  0.285714    0.081633
# 5   Português      10  2.285714    5.224490
# 6      Física      10  2.285714    5.224490

# %%
# Calculando a variância:
notas_fulano['(Desvio)^2'].sum() / (len(notas_fulano) - 1)
# Out:
# np.float64(4.57142857142857)

# %%
# Calculando a variância com o PANDAS:
variancia = notas_fulano['Fulano'].var()
variancia
# Out:
# 4.57142857142857

# %% [markdown]
# ## <font color=green>5.3 Desvio padrão</font>
# ***
#
# Uma das restrições da variância é o fato de fornecer medidas em quadrados das unidades originais - a variância de medidas de comprimento, por exemplo, é em unidades de área. Logo, o fato de as unidades serem diferentes dificulta a comparação da dispersão com as variáveis que a definem. Um modo de eliminar essa dificuldade é considerar sua raiz quadrada.

# %% [markdown]
# ### Desvio padrão populacional
#
# # $$\sigma = \sqrt{\frac 1n\sum_{i=1}^{n}(X_i-\mu)^2} \Longrightarrow \sigma = \sqrt{\sigma^2}$$

# %% [markdown]
# ### Desvio padrão amostral
#
# # $$S = \sqrt{\frac 1{n-1}\sum_{i=1}^{n}(X_i-\bar{X})^2} \Longrightarrow S = \sqrt{S^2}$$

# %%
# Desvio padrão é a raiz quadrada da variância:
np.sqrt(variancia)
# Out:
# np.float64(2.1380899352993947)

# %%
# Outra forma de calcular o desvio padrão com o pandas é a função .std():
desvio_padrao = notas_fulano['Fulano'].std()
desvio_padrao
# Out:
# 2.1380899352993947

# %%
df
# Out:
# Matérias    Fulano  Beltrano  Sicrano
# Matemática       8      10.0      7.5
# Português       10       2.0      8.0
# Inglês           4       0.5      7.0
# Geografia        8       1.0      8.0
# História         6       3.0      8.0
# Física          10       9.5      8.5
# Química          8      10.0      7.0

# %%
# Médias dos alunos:
df.mean()
# Out:
# Matérias
# Fulano      7.714286
# Beltrano    5.142857
# Sicrano     7.714286
# dtype: float64

# %%
# Mediana
df.median()
# Out:
# Matérias
# Fulano      8.0
# Beltrano    3.0
# Sicrano     8.0
# dtype: float64

# %%
# Moda
df.mode()
# Out:
# Matérias  Fulano  Beltrano  Sicrano
# 0              8      10.0      8.0

# %%
# Desvio Padrão
df.std()
# Out:
# Matérias
# Fulano      2.138090
# Beltrano    4.460141
# Sicrano     0.566947
# dtype: float64

# %%
# Qual o desvio padrão da variável IDADE?
dataset = pd.DataFrame({
    'Sexo': ['H', 'M', 'M', 'M', 'M', 'H', 'H', 'H', 'M', 'M'],
    'Idade': [53, 72, 54, 27, 30, 40, 58, 32, 44, 51]
})

dp = dataset['Idade'].std()
dp
# Out:
# 14.184890239656813

# %%
dp_mulheres = dataset.loc[dataset['Sexo'] == 'M', 'Idade'].std()
dp_mulheres
# Out:
# 16.64531966249572
